# %%
# neccessary imports
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
european_bank = pd.read_csv("../Data/European_Bank.csv")

# %%
# ploating the pairplot for the data and analazing which model fit that particullar mode
sns.pairplot(european_bank,hue="Exited")

# %%
## to check the columns name 
european_bank.columns.tolist()
# Out:
# ['Year',
#  'CustomerId',
#  'Surname',
#  'CreditScore',
#  'Geography',
#  'Gender',
#  'Age',
#  'Tenure',
#  'Balance',
#  'NumOfProducts',
#  'HasCrCard',
#  'IsActiveMember',
#  'EstimatedSalary',
#  'Exited']

# %%
european_bank.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  str
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  str
#  5   Gender           10000 non-null  str
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), str(3)
# memory usage: 1.2 MB

# %%
# basic information
# european_bank.info()
european_bank.boxplot(column=["Exited"])
# Out:
# <Axes: >

# %%
# ploting the histogram
european_bank.hist(column=["Exited"])
# Out:
# array([[<Axes: title={'center': 'Exited'}>]], dtype=object)

# %%
european_bank["Age"].max(),european_bank["Age"].min()
# Out:
# (np.int64(92), np.int64(18))

# %%
## For this input data bar chart does not work properly try another methods
# ploting bar chart 
numerical_data = european_bank.loc[:100,['Tenure','IsActiveMember','Exited']]
numerical_data.abs().plot(
    kind="bar", 
    stacked=True, 
    figsize=(10, 6),     # Sets a readable chart width and height
    edgecolor="white",   # Separates stacked segments clearly
    width=1,  # Makes bars thicker
)

# plt.title("Absolute Financial Metrics per Category", fontsize=14)
# plt.ylabel("Value")
# plt.xlabel("Index")
# plt.figure(figsize=(20,10))
# plt.xticks(rotation=90) # Tilts long labels so they do not overlap
# plt.tight_layout()       # Prevents label clipping
# plt.show()
# Out:
# <Axes: >

# %%
# head entry of the users
print(european_bank[(european_bank['IsActiveMember'] == 1) & (european_bank['Exited'] == 1)].count() )

print(european_bank[(european_bank['IsActiveMember'] == 0) & (european_bank['Exited'] == 1)].count())

print(european_bank[european_bank['IsActiveMember'] == 1].count())
# Out:
# Year               735
# CustomerId         735
# Surname            735
# CreditScore        735
# Geography          735
# Gender             735
# Age                735
# Tenure             735
# Balance            735
# NumOfProducts      735
# HasCrCard          735
# IsActiveMember     735
# EstimatedSalary    735
# Exited             735
# dtype: int64
# Year               1302
# CustomerId         1302
# Surname            1302
# CreditScore        1302
# Geography          1302
# Gender             1302
# Age                1302
# Tenure             1302
# Balance            1302
# NumOfProducts      1302
# HasCrCard          1302
# IsActiveMember     1302
# EstimatedSalary    1302
# Exited             1302
# dtype: int64
# Year               5151
# CustomerId         5151
# Surname            5151
# CreditScore        5151
# Geography          5151
# Gender             5151
# Age                5151
# Tenure             5151
# Balance            5151
# ...

# %%
european_bank[european_bank['Exited'] == 1]['Tenure'].min()
# Out:
# np.int64(0)

# %%
european_bank[european_bank['Exited'] == 0]['Tenure'].max()
# Out:
# np.int64(10)

# %%
# tail entry of the user
european_bank.tail()
# Out:
#       Year  CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 9995  2025    15606229   Obijiaku          771    France    Male   39       5
# 9996  2025    15569892  Johnstone          516    France    Male   35      10
# 9997  2025    15584532        Liu          709    France  Female   36       7
# 9998  2025    15682355  Sabbatini          772   Germany    Male   42       3
# 9999  2025    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 9995       0.00              2          1               0         96270.64
# 9996   57369.61              1          1               1        101699.77
# 9997       0.00              1          0               1         42085.58
# 9998   75075.31              2          1               0         92888.52
# 9999  130142.79              1          1               0         38190.78
#
#       Exited
# 9995       0
# 9996       0
# ...

# %%
# describing the numerical columns
european_bank.describe()
# Out:
#           Year    CustomerId   CreditScore           Age        Tenure  \
# count  10000.0  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    2025.0  1.569094e+07    650.528800     38.921800      5.012800
# std        0.0  7.193619e+04     96.653299     10.487806      2.892174
# min     2025.0  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2025.0  1.562853e+07    584.000000     32.000000      3.000000
# 50%     2025.0  1.569074e+07    652.000000     37.000000      5.000000
# 75%     2025.0  1.575323e+07    718.000000     44.000000      7.000000
# max     2025.0  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# ...

# %%
# to check the missing value corresponding to the coulmn
european_bank.isnull().sum()
# Out:
# Year               0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
# checking for duplicate entry
european_bank.duplicated().sum()
# Out:
# np.int64(0)

# %%
## selecting the column with the help of dtype
european_bank.select_dtypes(include=['int']).count()
# Out:
# Year              10000
# CustomerId        10000
# CreditScore       10000
# Age               10000
# Tenure            10000
# NumOfProducts     10000
# HasCrCard         10000
# IsActiveMember    10000
# Exited            10000
# dtype: int64

# %%
## analyzing the churn column
european_bank['Exited'].mean()*100
# Out:
# np.float64(20.369999999999997)

# %%
european_bank['Exited'].sum()
# 2037 users are exited in 10000
# 7963 user are not exited in 10000
# Out:
# np.int64(2037)

# %%
active_churn = european_bank[ (european_bank['Exited'] == 1 ) & (european_bank['IsActiveMember'] == 1)]
inactive_churn = european_bank[ (european_bank['Exited'] == 1 ) & (european_bank['IsActiveMember'] == 0)]

# %%
import seaborn as sns

# %%
num_column = european_bank.select_dtypes(exclude="str")
sns.heatmap(num_column,annot=True,fmt=".1f")
# Out:
# <Axes: >

# %% [markdown]
# There is total 10,000 entry
# columns : [Year, CustomerId, Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Geography = ['France', Germany', 'Spain']
#
# **before that i want to remove the Surname, Geography and Gender but it might be possible that Due to curtain problem a specific surname churn, geography brach does not perform well so in that case and lastly the Gender can be because many woman are house-wife that can impact there bank account mantanance**
#
# Active Churn = 735
# HasCrCard = 482
# CreditScore range 350-850 same as the whole data
# NumOfProducts 1-4 same
#
# I am now using all the columns and encoding the non numberic value to sum encoding for string to numberic conversion so that model can interpret and perform task and create an optimal model for that

# %%
# converting the data into two section input and output
# removing the Surname because there is 2000 unique Surname which is very vast then just remove it
x = european_bank.drop(['Exited','CustomerId','Surname'],axis=1) # geography and gender is str handle latter
y = european_bank['Exited']

# %%
# first convertin the geographu and gender columns to maping numberic value
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
x['Geography'] = le.fit_transform(x['Geography'])
x['Gender'] = le.fit_transform(x['Gender'])

# %%
# converting the data into 3 parts train 70%, verificationa 15% and testing 15%
from sklearn.model_selection import train_test_split
x_train, x_temp, y_train, y_temp = train_test_split(x,y,test_size=0.30, random_state=42, stratify=y)
# now conveting the x_temp, y_temp to verificationa and testing section
x_verify, x_test, y_verify, y_test = train_test_split(x_temp, y_temp,test_size=0.50, random_state=42, stratify=y_temp)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, roc_auc_score

# 1. Define a dictionary of models to test
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42),
    "XGBoost": XGBClassifier(random_state=42, eval_metric='logloss')
}

# 2. Loop through, train, and evaluate each model on your validation data
for name, model in models.items():
    # Train the model
    model.fit(x_train, y_train)
    
    # Predict probabilities for the validation set
    y_pred_proba = model.predict_proba(x_verify)[:, 1]
    y_pred = model.predict(x_verify)
    
    # Calculate ROC-AUC
    auc_score = roc_auc_score(y_verify, y_pred_proba)
    
    print(f"=== {name} ===")
    print(f"ROC-AUC Score: {auc_score:.4f}")
    print(classification_report(y_verify, y_pred))
    print("-" * 40)
# Out:
# === Logistic Regression ===
# ROC-AUC Score: 0.7744
#               precision    recall  f1-score   support
#
#            0       0.82      0.98      0.89      1194
#            1       0.69      0.14      0.24       306
#
#     accuracy                           0.81      1500
#    macro avg       0.75      0.56      0.57      1500
# weighted avg       0.79      0.81      0.76      1500
#
# ----------------------------------------
# === Random Forest ===
# ROC-AUC Score: 0.8749
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      1194
#            1       0.79      0.45      0.58       306
#
#     accuracy                           0.86      1500
#    macro avg       0.83      0.71      0.75      1500
# weighted avg       0.86      0.86      0.85      1500
#
# ----------------------------------------
# === XGBoost ===
# ROC-AUC Score: 0.8607
#               precision    recall  f1-score   support
#
# ...

# %%
# now trying to check the prediction for the test of the data
# model Random Forest because it has the accuracy 87%
model = RandomForestClassifier(random_state=42)
model.fit(x_train,y_train)
# y_pred_proba = model.predict_proba(x_temp)[:1]
y_pred = model.predict(x_verify)
print(classification_report(y_verify,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      1194
#            1       0.79      0.45      0.58       306
#
#     accuracy                           0.86      1500
#    macro avg       0.83      0.71      0.75      1500
# weighted avg       0.86      0.86      0.85      1500

# %%
import seaborn as sns

# %%
y_pred = model.predict(x_temp)
print(classification_report(y_temp,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92      2389
#            1       0.79      0.47      0.59       611
#
#     accuracy                           0.87      3000
#    macro avg       0.83      0.72      0.75      3000
# weighted avg       0.86      0.87      0.85      3000

# %%
y_pred = model.predict(x)
print(classification_report(y,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7963
#            1       0.96      0.84      0.89      2037
#
#     accuracy                           0.96     10000
#    macro avg       0.96      0.92      0.94     10000
# weighted avg       0.96      0.96      0.96     10000
